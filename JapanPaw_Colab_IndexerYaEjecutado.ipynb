# %% [markdown]
# # 🚀 Japan-Paw Catalog Indexer para Hayase
#
# Este notebook ejecuta el scraping completo de las series de Japan-Paw y vincula los torrents oficiales de Nyaa con WebSeeds HTTP directos en la nube de Google Colab a máxima velocidad sin consumir recursos ni ancho de banda de tu PC.
#
# ### Pasos para usar:
# 1. Ejecuta la **Celda 1** para clonar el repositorio.
# 2. Ejecuta la **Celda 2** para iniciar el pipeline de los 8,000 IDs (tomará ~25-35 minutos).
# 3. Ejecuta la **Celda 3** para descargar el archivo `dist_completo.zip` o la **Celda 4** para hacer push directo a GitHub.

# %%
# 1. Clonar repositorio e instalar dependencias
# !git clone https://github.com/JuanPerezC893/ExtenJap.git
# %cd ExtenJap
# !npm install
# Out:
# Cloning into 'ExtenJap'...
# remote: Enumerating objects: 244, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 244 (delta 47), reused 228 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (244/244), 2.44 MiB | 33.26 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# /content/ExtenJap
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏npm warn deprecated node-domexception@1.0.0: Use your platform's native DOMException instead
# ⠏⠋⠙⠹⠸⠼⠴⠦
# added 28 packages, and audited 29 packages in 4s
# ⠦
# ⠦11 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# found 0 vulnerabilities
# ⠦npm notice
# npm notice New major version of npm available! 10.8.2 -> 12.0.2
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v12.0.2
# npm notice To update run: npm install -g npm@12.0.2
# npm notice
# ⠦

# %%
# 2. Ejecutar Pipeline Automático con Concurrencia en la Nube
# Puedes definir el rango: por defecto del ID 1 al 8000
# (Se reanuda automáticamente saltando lo que ya esté descargado)
# !node auto-pipeline.mjs 1 8000
# Out:
# === PIPELINE AUTOMÁTICO DE JAPAN-PAW (IDs 1..8000) ===
#
# 1. Ejecutando scraper de pastes...
# Scrapeando v=1..8000 (19 ya en caché, 7981 pendientes con concurrencia 6)
#
# Listo. 19 series guardadas en ./raw-catalog.json
#
# 2. Vinculando torrents oficiales por CRC32...
# Buscando torrents por CRC32 para 0 episodios pendientes (concurrencia 5)...
#
# ¡Búsqueda por CRC32 terminada! 0 episodios vinculados.
#
# 3. Vinculando torrents restantes por título...
# Vinculando torrents para series pendientes...
#
# Procesando "Kimi no Koto ga Dai Dai Dai Dai Daisuki na 100-nin no Kanojo 3rd Season" (8 episodios pendientes)...
#   ✖ No encontrado en Nyaa: Kimi no Koto ga Dai Dai Dai Dai Daisuki na 100-nin no Kanojo 3rd Season Ep 1 (1080p)
#   ✖ No encontrado en Nyaa: Kimi no Koto ga Dai Dai Dai Dai Daisuki na 100-nin no Kanojo 3rd Season Ep 2 (1080p)
#   ✖ No encontrado en Nyaa: Kimi no Koto ga Dai Dai Dai Dai Daisuki na 100-nin no Kanojo 3rd Season Ep 3 (1080p)
#   ✖ No encontrado en Nyaa: Kimi no Koto ga Dai Dai Dai Dai Daisuki na 100-nin no Kanojo 3rd Season Ep 5 (1080p)
#   ✖ No encontrado en Nyaa: Kimi no Koto ga Dai Dai Dai Dai Daisuki na 100-nin no Kanojo 3rd Season Ep 7 (1080p)
#   ✖ No encontrado en Nyaa: Kimi no Koto ga Dai Dai Dai Dai Daisuki na 100-nin no Kanojo 3rd Season Ep 8 (1080p)
#   ✖ No encontrado en Nyaa: Kimi no Koto ga Dai Dai Dai Dai Daisuki na 100-nin no Kanojo 3rd Season Ep 9 (1080p)
#   ✖ No encontrado en Nyaa: Kimi no Koto ga Dai Dai Dai Dai Daisuki na 100-nin no Kanojo 3rd Season Ep 10 (1080p)
#
# Procesando "Sekaiichi Hatsukoi" (12 episodios pendientes)...
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 3 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 4 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 5 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 6 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 7 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 8 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 9 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 10 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 11 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 12 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 13 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi Ep 14 (720p)
#
# Procesando "Sekaiichi Hatsukoi 2" (10 episodios pendientes)...
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi 2 Ep 3 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi 2 Ep 4 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi 2 Ep 5 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi 2 Ep 6 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi 2 Ep 7 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi 2 Ep 8 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi 2 Ep 9 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi 2 Ep 10 (720p)
#   ✖ No encontrado en Nyaa: Sekaiichi Hatsukoi 2 Ep
#   ✔ Ep 2 (1080p): hash 01e1a65d93439f8e9437a8c1fadaab7bd1216e89
#   ✔ Ep 3 (1080p): hash e31db1e06675527abf7575c64ce6278ab100aba9
#   ✔ Ep 5 (1080p): hash 65e9cdf69557968132faaa5e1628975de9115124
#   ✔ Ep 6 (1080p): hash e6d60499e7122dbcec91c64dc5db7fd0d67599f4
#   ✔ Ep 7 (1080p): hash 9b268f385a9aa128fd87fd590cf35cbef6b88424
#   ✔ Ep 8 (1080p): hash eaa238a22b551b34cb502862fe6a9925891adb30
#   ✔ Ep 9 (1080p): hash 70209ec0b63ef67acd3f11b630295132b82100e1
#
# Procesando "Mushoku Tensei III: Isekai Ittara Honki Dasu" (11 episodios pendientes)...
#   ✔ Ep 1 (1080p): hash fb52f88f106ccb015aa327d0e2bf0cba6f17ac81
#   ✔ Ep 2 (1080p): hash 5592e4d10d4a307b1a53dc9fd61f76e52379b25e
#   ✔ Ep 3 (1080p): hash 505b1ae4fa45aae5f9145ef7f1132a1e864d1889
#   ✔ Ep 4 (1080p): hash 15782e68fa0831134de4c956c41b27626b630d14
#   ✔ Ep 5 (1080p): hash 67b5e307039c6ad5a926f69e9eab35c300601b69
#   ✔ Ep 6 (1080p): hash 2c2865b034190b36a742d88efcdb8632ba52bf35
#   ✔ Ep 7 (1080p): hash 93b67d25aec91283748931247397d390e02482ca
#   ✔ Ep 8 (1080p): hash 0fd6b371f528febceba148d0cd3fe3bf958d6505
#   ✔ Ep 9 (1080p): hash a44d400d315cc7140292c067cf2a510e00b054f6
#   ✔ Ep 10 (1080p): hash 5c6e812b9cac8eb54185599f0e0c77b3c3e20b3a
#   ✔ Ep 11 (1080p): hash 5c6e812b9cac8eb54185599f0e0c77b3c3e20b3a
#
# Procesando "Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu II" (8 episodios pendientes)...
#   ✖ No encontrado en Nyaa: Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu II Ep 1 (1080p)
#   ✖ No encontrado en Nyaa: Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu II Ep 2 (1080p)
#   ✖ No encontrado en Nyaa: Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu II Ep 3 (1080p)
#   ✖ No encontrado en Nyaa: Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu II Ep 4 (1080p)
#   ✖ No encontrado en Nyaa: Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu II Ep 5 (1080p)
#   ✖ No encontrado en Nyaa: Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu II Ep 6 (1080p)
#   ✖ No encontrado en Nyaa: Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu II Ep 8 (1080p)
#   ✖ No encontrado en Nyaa: Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu II Ep 9 (1080p)
#
# ¡Listo! 44 episodios vinculados con torrent oficial + WebSeed.
#
# 4. Compilando distribución para GitHub...
# Catálogo indexado: 19 series (20 episodios en serie 1)
# Preparado: https://raw.githubusercontent.com/JuanPerezC893/ExtenJap/main/dist/manifest.json
#
# === PIPELINE COMPLETADO EXITOSAMENTE ===

# %%
# 3. Descargar el resultado en tu PC (Opción más fácil sin tokens)
# !zip -r /content/dist_completo.zip dist/ raw-catalog.json
from google.colab import files
files.download('/content/dist_completo.zip')

# %%
# 4. (Alternativa) Subir directamente a GitHub desde Colab
# Solo necesitas un Personal Access Token de GitHub (con permisos de repo)
import getpass
token = getpass.getpass('Introduce tu GitHub Personal Access Token: ')
# !git config --global user.name "JuanPerezC893"
# !git config --global user.email "juan.perezc@mayor.cl"
# !git add -f raw-catalog.json dist/
# !git commit -m "Catalogo completo indexado desde Google Colab"
# !git push https://{token}@github.com/JuanPerezC893/ExtenJap.git main
